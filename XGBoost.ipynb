# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, matthews_corrcoef
import numpy as np

# XGBoost Classifier
xgb = XGBClassifier(eval_metric="mlogloss", random_state=42)
xgb.fit(X_train_np, y_train_mapped)
y_pred_xgb = xgb.predict(X_test_np)

print("\nXGBoost Classifier")
print("Accuracy:", accuracy_score(y_test_mapped, y_pred_xgb))
print("Precision:", precision_score(y_test_mapped, y_pred_xgb, average="macro"))
print("Recall:", recall_score(y_test_mapped, y_pred_xgb, average="macro"))
print("F1 Score:", f1_score(y_test_mapped, y_pred_xgb, average="macro"))
print("MCC:", matthews_corrcoef(y_test_mapped, y_pred_xgb))

# For ROC-AUC, we need probability scores
y_prob_xgb = xgb.predict_proba(X_test_np)
print("ROC-AUC:", roc_auc_score(y_test_mapped, y_prob_xgb, multi_class="ovr"))

print("Confusion Matrix:\n", confusion_matrix(y_test_mapped, y_pred_xgb))
